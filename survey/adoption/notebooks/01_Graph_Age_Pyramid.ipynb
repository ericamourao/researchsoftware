# %%
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-448cf1c2-cf37-4f95-94f9-3426a985d0a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-448cf1c2-cf37-4f95-94f9-3426a985d0a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_name = next(iter(uploaded))
file_name
# Out:
# 'Survey_Perfil_Todos_Usuario_e_Desenvolvedor.xlsx'

# %%
# %matplotlib inline

import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
from functools import reduce
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import statistics as s

df = pd.read_excel(file_name)

df
# Out:
#      PERFIL  TEMPO_USO  FREQUENCIA_USO  IDADE  GENERO  FORMACAO  \
# 0       1.0        3.0             3.0    2.0     1.0       4.0
# 1       1.0        4.0             4.0    1.0     2.0       4.0
# 2       1.0        3.0             4.0    2.0     2.0       2.0
# 3       1.0        2.0             3.0    3.0     1.0       4.0
# 4       1.0        1.0             5.0    3.0     1.0       4.0
# ..      ...        ...             ...    ...     ...       ...
# 168     2.0        4.0             4.0    2.0     2.0       4.0
# 169     2.0        2.0             3.0    2.0     2.0       4.0
# 170     2.0        1.0             3.0    1.0     2.0       2.0
# 171     2.0        4.0             3.0    2.0     2.0       5.0
# 172     2.0        4.0             5.0    2.0     2.0       5.0
#
#      ANOS_EXPERIENCIA  UTILIZACAO_D01F01  UTILIZACAO_D01F02  \
# 0                 3.0                5.0                5.0
# 1                 2.0                4.0                2.0
# ...

# %%
# Selecting columns
df1 = df.loc[:, lambda df:['IDADE','GENERO'] ]
df1.columns = ['Age','Gender'] 
df1

df3_grafico  = df1

df3_grafico
# Out:
#      Age  Gender
# 0    2.0     1.0
# 1    1.0     2.0
# 2    2.0     2.0
# 3    3.0     1.0
# 4    3.0     1.0
# ..   ...     ...
# 168  2.0     2.0
# 169  2.0     2.0
# 170  1.0     2.0
# 171  2.0     2.0
# 172  2.0     2.0
#
# [173 rows x 2 columns]

# %%
df3_grafico = pd.DataFrame({'60 years or older':[len(df1[(df1['Age'] == 5.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 5.0) & (df1['Gender'] == 2.0)]), len(df1[(df1['Age'] == 5.0) & (df1['Gender'] == 3.0)]), len(df1[(df1['Age'] == 5.0) & (df1['Gender'] == 4.0)])],
                            'Between 50 and 59 years old':[len(df1[(df1['Age'] == 4.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 4.0) & (df1['Gender'] == 2.0)]), len(df1[(df1['Age'] == 4.0) & (df1['Gender'] == 3.0)]), len(df1[(df1['Age'] == 4.0) & (df1['Gender'] == 4.0)])],
                           'Between 40 and 49 years old':[len(df1[(df1['Age'] == 3.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 3.0) & (df1['Gender'] == 2.0)]), len(df1[(df1['Age'] == 3.0) & (df1['Gender'] == 3.0)]), len(df1[(df1['Age'] == 3.0) & (df1['Gender'] == 4.0)])],
                           'Between 30 and 39 years old':[len(df1[(df1['Age'] == 2.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 2.0) & (df1['Gender'] == 2.0)]), len(df1[(df1['Age'] == 2.0) & (df1['Gender'] == 3.0)]), len(df1[(df1['Age'] == 2.0) & (df1['Gender'] == 4.0)])],
                           'Between 18 and 29 years old':[len(df1[(df1['Age'] == 1.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 1.0) & (df1['Gender'] == 2.0)]), len(df1[(df1['Age'] == 1.0) & (df1['Gender'] == 3.0)]), len(df1[(df1['Age'] == 1.0) & (df1['Gender'] == 4.0)])],
                            })

index_ = ['Female', 'Male', 'Other' , 'I prefer not inform']
df3_grafico.index = index_

df3_grafico
# Out:
#                      60 years or older  Between 50 and 59 years old  \
# Female                               2                            6
# Male                                 5                           12
# Other                                0                            0
# I prefer not inform                  0                            0
#
#                      Between 40 and 49 years old  Between 30 and 39 years old  \
# Female                                        12                           19
# Male                                          22                           47
# Other                                          0                            0
# I prefer not inform                            0                            2
#
#                      Between 18 and 29 years old
# Female                                         9
# Male                                          37
# Other                                          0
# ...

# %%
df7 = df3_grafico.transpose()

#df7.index.names = ['index']
#df7.columns.names = ['Age']
df7
# Out:
#                              Female  Male
# 60 years or older                 2     5
# Between 50 and 59 years old       6    12
# Between 40 and 49 years old      12    22
# Between 30 and 39 years old      19    47
# Between 18 and 29 years old       9    37

# %%
df3_grafico = pd.DataFrame({'60 years or older':[len(df1[(df1['Age'] == 5.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 5.0) & (df1['Gender'] == 2.0)])],
                            'Between 50 and 59 years old':[len(df1[(df1['Age'] == 4.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 4.0) & (df1['Gender'] == 2.0)])],
                           'Between 40 and 49 years old':[len(df1[(df1['Age'] == 3.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 3.0) & (df1['Gender'] == 2.0)])],
                           'Between 30 and 39 years old':[len(df1[(df1['Age'] == 2.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 2.0) & (df1['Gender'] == 2.0)])],
                           'Between 18 and 29 years old':[len(df1[(df1['Age'] == 1.0) & (df1['Gender'] == 1.0)]), len(df1[(df1['Age'] == 1.0) & (df1['Gender'] == 2.0)])]
                            })

index_ = ['Female', 'Male']
df3_grafico.index = index_

df3_grafico
# Out:
#         60 years or older  Between 50 and 59 years old  \
# Female                  2                            6
# Male                    5                           12
#
#         Between 40 and 49 years old  Between 30 and 39 years old  \
# Female                           12                           19
# Male                             22                           47
#
#         Between 18 and 29 years old
# Female                            9
# Male                             37

# %%
df3_grafico

center_aligned_df = df3_grafico.style.set_properties(**{'text-align': 'center'})
 
center_aligned_df = center_aligned_df.set_table_styles(
[dict(selector = 'th', props=[('text-align', 'center')])])

pd.options.display.float_format = '{:.2f}'.format

center_aligned_df

df7 = df3_grafico.transpose()

df7
# Out:
#                              Female  Male
# 60 years or older                 2     5
# Between 50 and 59 years old       6    12
# Between 40 and 49 years old      12    22
# Between 30 and 39 years old      19    47
# Between 18 and 29 years old       9    37

# %%
df7['Female']  = ((df7['Female']/171)*100)
df7['Male']  = ((df7['Male']/171)*100)

df7
# Out:
#                              Female  Male
# 60 years or older              1.17  2.92
# Between 50 and 59 years old    3.51  7.02
# Between 40 and 49 years old    7.02 12.87
# Between 30 and 39 years old   11.11 27.49
# Between 18 and 29 years old    5.26 21.64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools


#df7 = df3_grafico.transpose()

#df7 = df3_grafico


plt.rcParams["figure.figsize"] = (10, 8)

AgeClass = ['60 years or older', 'Between 50 and 59 years old', 'Between 40 and 49 years old', 'Between 30 and 39 years old', 'Between 18 and 29 years old']
    
# convert male counts to negative
df7['Male'] = df7['Male']*(-1)

#pd.options.display.float_format = '{:.2f}'.format

df7

#df8 = df7.transpose()

df8 = df7

#bar_plot = sns.barplot(x=df8['Female'], y=df8['Male'], data=df8, hue=None, order=AgeClass, orient='horizontal', dodge=False)
ax = sns.barplot(x=df8['Female'], y=df8.index, data=df8, hue=None, order=AgeClass, orient='horizontal', dodge=False, color ='#FF6D01')
ax = sns.barplot(x=df8['Male'], y=df8.index, data=df8, hue=None , order=AgeClass, orient='horizontal', dodge=False, color ='#4285F4')


## Width of bars (everything above 1 will overlap)
FigBarsWidth=0.8
## FontSize of bar lables
FigBarsFontSize=10
## Unit to display within bars
FigBarUnit="%"

for rect in ax.patches:
    # Find where everything is located
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    # ax.text(x, y, text)
    label_x = x + width / 2
    label_y = y + height / 2

    # The width of the bar is the data value and can be used as the label
    label_text = ""
    # plot only when width is greater than specified value
    if height > 0:
            
      label_text = f'{width:.2f}' + FigBarUnit  ##### use {width:.2f} or {width:.3f} to increase precision  ####
      
      # plot only when height is greater than specified value 
      #ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=FigBarsFontSize)
   
    if width > 2:
      label_text = f'{width:.2f}' + FigBarUnit  ##### use {width:.2f} or {width:.3f} to increase precision  ####
      # plot only when height is greater than specified value
      ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=FigBarsFontSize)
    # plot only when width is greater than specified value <= 2 
    else:
      if width >= 0:
        label_text = f'{width:.2f}' + FigBarUnit  ##### use {width:.2f} or {width:.3f} to increase precision  ####
        ax.text(label_x, label_y, label_text, ha='left', va='top', fontsize=FigBarsFontSize)
      else:
        label_text = f'{width:.2f}' + FigBarUnit  ##### use {width:.2f} or {width:.3f} to increase precision  ####
        ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=FigBarsFontSize)  



ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

ax.set_xlim(-30, 30)
ticks = ax.set_xticks([-30, -15, 0, 15, 30])
#ax.set_xticklabels(("0%", "25%", "50%", "75%", "100%")) 

plt.title("Age Pyramid  - Distribution of Genders",  fontsize=14, weight='bold')
plt.xlabel("Male/Female")

plt.grid(True, color = "grey", axis='x', linewidth = "0.1", linestyle = "solid")

plt.savefig('AgePyramid.png')

ax.legend(loc='upper right', ncol=2, title="Male/Female", borderaxespad=0, bbox_to_anchor=(1.15, 1))
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
